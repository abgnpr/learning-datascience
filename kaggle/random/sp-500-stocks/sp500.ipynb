# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('sp500_companies.csv')

# %%
df.head(10)
# Out:
#   Exchange Symbol                    Shortname                 Longname  \
# 0      NMS   MSFT        Microsoft Corporation    Microsoft Corporation
# 1      NMS   AAPL                   Apple Inc.               Apple Inc.
# 2      NMS   NVDA           NVIDIA Corporation       NVIDIA Corporation
# 3      NMS  GOOGL                Alphabet Inc.            Alphabet Inc.
# 4      NMS   GOOG                Alphabet Inc.            Alphabet Inc.
# 5      NMS   AMZN             Amazon.com, Inc.         Amazon.com, Inc.
# 6      NMS   META         Meta Platforms, Inc.     Meta Platforms, Inc.
# 7      NYQ  BRK-B  Berkshire Hathaway Inc. New  Berkshire Hathaway Inc.
# 8      NYQ    LLY        Eli Lilly and Company    Eli Lilly and Company
# 9      NMS   AVGO                Broadcom Inc.            Broadcom Inc.
#
#                    Sector                        Industry  Currentprice  \
# 0              Technology       Software - Infrastructure        406.32
# ...

# %%
cols_na_count = df.isna().sum()
cols_na_count[cols_na_count>0]
# Out:
# Sector                1
# Industry              1
# Ebitda               29
# Revenuegrowth         2
# State                12
# Fulltimeemployees     4
# dtype: int64

# %%
sns.heatmap(df[df.columns[df.dtypes != 'object']].corr(), annot=True, cmap='Blues')
# Out:
# <Axes: >

# %%
sns.lineplot(data=df, x='Marketcap', y='Weight')
# Out:
# <Axes: xlabel='Marketcap', ylabel='Weight'>

# %%
df.loc[df['Revenuegrowth'].nlargest(10).index][['Shortname', 'Revenuegrowth']]
# Out:
#                       Shortname  Revenuegrowth
# 2            NVIDIA Corporation          2.653
# 54              Blackstone Inc.          1.736
# 177  Super Micro Computer, Inc.          1.032
# 469       Wynn Resorts, Limited          0.831
# 72      Micron Technology, Inc.          0.577
# 278     Extra Space Storage Inc          0.572
# 227  Prudential Financial, Inc.          0.561
# 374         Synchrony Financial          0.526
# 179         Newmont Corporation          0.502
# 460                 Qorvo, Inc.          0.445

# %%
df.sort_values(by='Revenuegrowth')
# Out:
#     Exchange Symbol                        Shortname  \
# 411      NGM   ENPH             Enphase Energy, Inc.
# 215      NMS   MRNA                    Moderna, Inc.
# 59       NYQ    PFE                     Pfizer, Inc.
# 412      NYQ     CF     CF Industries Holdings, Inc.
# 400      NYQ   EXPD  Expeditors International of Was
# ..       ...    ...                              ...
# 177      NMS   SMCI       Super Micro Computer, Inc.
# 54       NYQ     BX                  Blackstone Inc.
# 2        NMS   NVDA               NVIDIA Corporation
# 212      NYQ    GEV                  GE Vernova Inc.
# 313      NMS    WDC      Western Digital Corporation
#
#                                          Longname              Sector  \
# 411                          Enphase Energy, Inc.          Technology
# 215                                 Moderna, Inc.          Healthcare
# 59                                    Pfizer Inc.          Healthcare
# ...

# %%
sns.histplot(df.sort_values(by='Weight')['Weight'], bins=50, cumulative=True)
# Out:
# <Axes: xlabel='Weight', ylabel='Count'>

# %%
500//10
# Out:
# 50
