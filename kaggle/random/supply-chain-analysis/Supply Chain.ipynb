# %% [markdown]
# # Supply Chain

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('supply_chain_data.csv')

# %%
df.head()
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
# 3     skincare  SKU3  61.163343            68                       83
# 4     skincare  SKU4   4.805496            26                      871
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626               Unknown             1          10
# 3        7766.836426            Non-binary            23          13
# 4        2686.505152            Non-binary             5           3
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# ...

# %%
df.shape
# Out:
# (100, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Product type             100 non-null    object
#  1   SKU                      100 non-null    object
#  2   Price                    100 non-null    float64
#  3   Availability             100 non-null    int64
#  4   Number of products sold  100 non-null    int64
#  5   Revenue generated        100 non-null    float64
#  6   Customer demographics    100 non-null    object
#  7   Stock levels             100 non-null    int64
#  8   Lead times               100 non-null    int64
#  9   Order quantities         100 non-null    int64
#  10  Shipping times           100 non-null    int64
#  11  Shipping carriers        100 non-null    object
#  12  Shipping costs           100 non-null    float64
#  13  Supplier name            100 non-null    object
# ...

# %%
df.isna().sum()
# Out:
# Product type               0
# SKU                        0
# Price                      0
# Availability               0
# Number of products sold    0
# Revenue generated          0
# Customer demographics      0
# Stock levels               0
# Lead times                 0
# Order quantities           0
# Shipping times             0
# Shipping carriers          0
# Shipping costs             0
# Supplier name              0
# Location                   0
# Lead time                  0
# Production volumes         0
# Manufacturing lead time    0
# Manufacturing costs        0
# Inspection results         0
# Defect rates               0
# Transportation modes       0
# Routes                     0
# Costs                      0
# dtype: int64

# %%
sns.barplot(data=df, x='Product type', y='Price', hue='Product type')
# Out:
# <Axes: xlabel='Product type', ylabel='Price'>

# %%
plt.figure(figsize=(20, 20))
cm = df[df.columns[df.dtypes != 'object']].corr()
sns.heatmap(cm, annot=True, cmap='Blues')
plt.draw()

# %%
pd.crosstab(df['Product type'], df['Customer demographics'])
# Out:
# Customer demographics  Female  Male  Non-binary  Unknown
# Product type
# cosmetics                  10     4           5        7
# haircare                    2    10           7       15
# skincare                   13     7          11        9

# %%
[1, 2, 3] - [ 2 ]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9124/2451879924.py in <module>
# ----> 1 [1, 2, 3] - [2]
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
u = pd.Series({ col: df[col].nunique() for col in df.columns[df.dtypes == 'object'] }) 
u[u<=5].index
# Out:
# Index(['Product type', 'Customer demographics', 'Shipping carriers',
#        'Supplier name', 'Location', 'Inspection results',
#        'Transportation modes', 'Routes'],
#       dtype='object')
